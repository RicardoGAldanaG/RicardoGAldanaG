# %% [markdown]
# <a href="https://colab.research.google.com/github/RicardoGAldanaG/RicardoGAldanaG/blob/main/SentenciasPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
edad = 12
if edad >= 15:
  print("eres mayor de edad")
elif edad >= 12:
  print("eres adolescente")
else:
  print("eres niño")
# Out:
# eres adolescente

# %%
for numero in range(5):
    print("numero:", numero) # Indented this line by 4 spaces
# Out:
# numero: 0
# numero: 1
# numero: 2
# numero: 3
# numero: 4

# %%
contador = 1
while contador < 3:
  print ("contador:", contador)
  contador += 1
# Out:
# contador: 1
# contador: 2

# %%
for numero in range(10):
  if numero == 5:
      continue
      print(numero)

# %%
import random

secreto = random.randint(1,10)
intentos = 0

while true:
  intento = int(input("Adivina el numero (1 al 10):"))
  intentos += 1

  if intento == secreto:
import random

secreto = random.randint(1,10)
intentos = 0

while True:
  intento = int(input("Adivina el numero (1 al 10):"))
  intentos += 1

  if intento == secreto:
     print("correcto! lo adivinaste en", intentos, "intento(s).")
     break
  elif intento < secreto:
     print("muy bajo, intenta de nuevo.")
  else:
     print("muy alto, intenta de nuevo.")
     print("muy alto, intenta de nuevo.")
# Out:
#   File "<ipython-input-13-5a71ba2aea8d>", line 11
#     import random
#                  ^
# IndentationError: expected an indented block after 'if' statement on line 10

# %%
import random

numero_secreto = random.randint(1, 10)
print("Bienvenido al juego de adivina el numero")
print("Estoy pensando en un número del 1 al 10")
while True:
    intento = int(input("¿Cuál crees que es el número?"))
    if intento == numero_secreto:
        print("¡Felicidades! Adivinaste el número en", intentos, "intentos.")
        break
    elif intento < numero_secreto:
        print("Demasiado bajo, intenta de nuevo.")
    else:
        print("Demasiado alto, intenta de nuevo.")
        #El programa sigue la cuenta de intento aún cuando se reinicia el juego
# Out:
# Bienvenido al juego de adivina el numero
# Estoy pensando en un número del 1 al 10
# ¿Cuál crees que es el número?5
# Demasiado bajo, intenta de nuevo.
# ¿Cuál crees que es el número?8
# Demasiado alto, intenta de nuevo.
# ¿Cuál crees que es el número?6
# ¡Felicidades! Adivinaste el número en 7 intentos.

# %%
for i in range(10):
    if i % 2 == 0:
      continue
    print(i)
else:
    print("bucle terminado")
# Out:
# 1
# 3
# 5
# 7
# 9
# bucle terminado
